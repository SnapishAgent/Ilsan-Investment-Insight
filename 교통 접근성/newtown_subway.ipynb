# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
from math import pi 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
subway_file_path = 'C:/Users/saeya/Downloads/전체_도시철도역사정보_20240930.xlsx'
subway_data = pd.read_excel(subway_file_path)

# 데이터 확인
subway_data
# Out:
#        역번호           역사명   노선번호     노선명                                영문역사명  \
# 0     0124  청량리(서울시립대입구)  I4101     1호선  Cheongnyangni (University of Seoul)
# 1     0125           제기동  I4101     1호선                             Jegidong
# 2     0126           신설동  I4101     1호선                          Sinseoldong
# 3     0127           동묘앞  I4101     1호선                              Dongmyo
# 4     0128           동대문  I4101     1호선                           Dongdaemun
# ...    ...           ...    ...     ...                                  ...
# 1068   105         워터파크역  S28M1  자기부상철도                   Water Park Station
# 1069   106           용유역  S28M1  자기부상철도                       Yongyu Station
# 1070  0408        별내별가람역  I4104     진접선                   ByeollaeByeolgaram
# 1071  0406           오남역  I4104     진접선                                 Onam
# 1072  0405           진접역  I4104     진접선                              Jinjeop
#
# ...

# %%
#  고양시(5개): 대화역, 주엽역, 정발산역, 마두역, 백석역 (GTX-A: 킨텍스, 대곡역)
#  성남시(6개): 성남역, 이매역, 서현역, 수내역, 정자역, 미금역 (만약에 필요하면 모란역, 오리역, 동천역)

# 동천역 X 동천 O


desired_values = ["대화역","주엽역","정발산역", "마두역", "백석역","성남역", "이매역", "서현역", "수내역", "정자역", "미금역" ,"모란역", "오리역", "동천","대곡역"]  # 원하는 값을 입력하세요
filtered_df = subway_data[subway_data['역사명'].isin(desired_values)]

# 필터링된 데이터 출력
print(filtered_df)

#filtered_df.to_csv("filtered_subway_station_data_근처역포함.csv", index=False, encoding="utf-8-sig")
# Out:
#        역번호   역사명   노선번호    노선명        영문역사명 한자역사명     환승역구분 환승노선번호     환승노선명  \
# 279   1502   이매역  I41K5    경강선         Imae    二梅       환승역  I28K1       분당선
# 289   1512   성남역  I41K5    경강선     Seongnam    城南       일반역    NaN       NaN
# 413   1953   대곡역  I4108  경의중앙선       Daegok   大 谷       환승역  I4106  일산선, 서해선
# 791   1853   모란역  I28K1    분당선        Moran   牡 丹       환승역  S1108       8호선
# 793   1860   이매역  I28K1    분당선         Imae   二 梅       환승역  I41K5       경강선
# 794   1855   서현역  I28K1    분당선     Seohyeon   書 峴       일반역    NaN       NaN
# 795   1856   수내역  I28K1    분당선        Sunae   藪 內       일반역    NaN       NaN
# 796   1857   정자역  I28K1    분당선      Jeongja   亭 子       환승역  I41D1      신분당선
# 797   1858   미금역  I28K1    분당선       Migeum   美 金       일반역    NaN       NaN
# 798   1859   오리역  I28K1    분당선          Ori   梧 里       일반역    NaN       NaN
# 912   D014    동천  I11D1   신분당선    Dongcheon    東川  도시철도 일반역    NaN       NaN
# ...

# %%
#  고양시(5개): 대화역, 주엽역, 정발산역, 마두역, 백석역 (GTX-A: 킨텍스, 대곡역)
#  성남시(6개): 성남역, 이매역, 서현역, 수내역, 정자역, 미금역 (만약에 필요하면 모란역, 오리역, 동천역)

# 동천역 X 동천 O


desired_values = ["대화역","주엽역","정발산역", "마두역", "백석역","성남역", "이매역", "서현역", "수내역", "정자역", "미금역" ]  # 원하는 값을 입력하세요
filtered_df = subway_data[subway_data['역사명'].isin(desired_values)]

# 필터링된 데이터 출력
print(filtered_df)

#filtered_df.to_csv("filtered_subway_station_data.csv", index=False, encoding="utf-8-sig")
# Out:
#        역번호   역사명   노선번호  노선명        영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명        역위도  \
# 279   1502   이매역  I41K5  경강선         Imae    二梅   환승역  I28K1   분당선  37.394736
# 289   1512   성남역  I41K5  경강선     Seongnam    城南   일반역    NaN   NaN  37.394709
# 793   1860   이매역  I28K1  분당선         Imae   二 梅   환승역  I41K5   경강선  37.395846
# 794   1855   서현역  I28K1  분당선     Seohyeon   書 峴   일반역    NaN   NaN  37.384931
# 795   1856   수내역  I28K1  분당선        Sunae   藪 內   일반역    NaN   NaN  37.378435
# 796   1857   정자역  I28K1  분당선      Jeongja   亭 子   환승역  I41D1  신분당선  37.366037
# 797   1858   미금역  I28K1  분당선       Migeum   美 金   일반역    NaN   NaN  37.350078
# 1059  1954   백석역  I4106  일산선     Baekseok   白 石   일반역    NaN   NaN  37.642973
# 1060  1955   마두역  I4106  일산선         Madu   馬 頭   일반역    NaN   NaN  37.652185
# 1061  1956  정발산역  I4106  일산선  Jeongbalsan   鼎鉢山   일반역    NaN   NaN  37.659709
# 1062  1957   주엽역  I4106  일산선       Juyeop   注 葉   일반역    NaN   NaN  37.670138
# ...

# %%
ilsan_subway= ["대화역","주엽역","정발산역", "마두역", "백석역"]  # 원하는 값을 입력하세요
filtered_ilsan = subway_data[subway_data['역사명'].isin(ilsan_subway)]

# 필터링된 데이터 출력
print(filtered_ilsan)

#filtered_ilsan.to_csv("filtered_subway_station_data_일산신도시.csv", index=False, encoding="utf-8-sig")
# Out:
#        역번호   역사명   노선번호  노선명        영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명        역위도  \
# 1059  1954   백석역  I4106  일산선     Baekseok   白 石   일반역    NaN   NaN  37.642973
# 1060  1955   마두역  I4106  일산선         Madu   馬 頭   일반역    NaN   NaN  37.652185
# 1061  1956  정발산역  I4106  일산선  Jeongbalsan   鼎鉢山   일반역    NaN   NaN  37.659709
# 1062  1957   주엽역  I4106  일산선       Juyeop   注 葉   일반역    NaN   NaN  37.670138
# 1063  1958   대화역  I4106  일산선       Daehwa   大 化   일반역    NaN   NaN  37.675883
#
#              역경도   운영기관명                                 역사도로명주소     역사전화번호  \
# 1059  126.788109  한국철도공사                   경기도 고양시 일산동구 중앙로 1042  1544-7788
# 1060  126.777641  한국철도공사           경기도 고양시 일산동구 중앙로 지하 1180(마두동)  1544-7788
# 1061  126.773254  한국철도공사  경기도 고양시 일산동구 마두 1동 1123(일산동구 중앙로 1270)  1544-7788
# 1062  126.761232  한국철도공사        경기도 고양시 일산서구 중앙로 1432(주엽동 166-7)  1544-7788
# 1063  126.747756  한국철도공사         경기도 고양시 일산서구 중앙로 1569(대화동 2221)  1544-7788
#
#         데이터기준일자
# 1059 2024-05-31
# ...

# %%
bundang_subway= ["이매역", "서현역", "수내역", "정자역", "미금역","오리역" ]  # 원하는 값을 입력하세요
filtered_bundang = subway_data[subway_data['역사명'].isin(bundang_subway)]

# 필터링된 데이터 출력
print(filtered_bundang)

filtered_bundang.to_csv("filtered_subway_station_data_분당신도시.csv", index=False, encoding="utf-8-sig")
# Out:
#       역번호  역사명   노선번호  노선명     영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명        역위도  \
# 279  1502  이매역  I41K5  경강선      Imae    二梅   환승역  I28K1   분당선  37.394736
# 793  1860  이매역  I28K1  분당선      Imae   二 梅   환승역  I41K5   경강선  37.395846
# 794  1855  서현역  I28K1  분당선  Seohyeon   書 峴   일반역    NaN   NaN  37.384931
# 795  1856  수내역  I28K1  분당선     Sunae   藪 內   일반역    NaN   NaN  37.378435
# 796  1857  정자역  I28K1  분당선   Jeongja   亭 子   환승역  I41D1  신분당선  37.366037
# 797  1858  미금역  I28K1  분당선    Migeum   美 金   일반역    NaN   NaN  37.350078
# 798  1859  오리역  I28K1  분당선       Ori   梧 里   일반역    NaN   NaN  37.339832
#
#             역경도   운영기관명                          역사도로명주소     역사전화번호    데이터기준일자
# 279  127.123048  한국철도공사             경기도 성남시 분당구 성남대로 738  1544-7788 2024-05-31
# 793  127.128272  한국철도공사              경기도 성남시 성남대로 지하 738  1544-7788 2024-05-31
# 794  127.123249  한국철도공사          경기도 성남시 분당구 성남대로 지하 601  1544-7788 2024-05-31
# ...

# %%
newtown_subway= ["대화역","주엽역","정발산역", "마두역", "백석역","이매역", "서현역", "수내역", "정자역", "미금역","오리역","야탑역","모란역" ]  # 원하는 값을 입력하세요
filtered_newtown = subway_data[subway_data['역사명'].isin(newtown_subway)]

# 필터링된 데이터 출력
filtered_newtown

#filtered_newtown.to_csv("filtered_subway_station_data_일산분당신도시.csv", index=False, encoding="utf-8-sig")
# Out:
#        역번호   역사명   노선번호  노선명        영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명        역위도  \
# 279   1502   이매역  I41K5  경강선         Imae    二梅   환승역  I28K1   분당선  37.394736
# 791   1853   모란역  I28K1  분당선        Moran   牡 丹   환승역  S1108   8호선  37.432124
# 792   1854   야탑역  I28K1  분당선        Yatap   野 塔   일반역    NaN   NaN  37.411320
# 793   1860   이매역  I28K1  분당선         Imae   二 梅   환승역  I41K5   경강선  37.395846
# 794   1855   서현역  I28K1  분당선     Seohyeon   書 峴   일반역    NaN   NaN  37.384931
# 795   1856   수내역  I28K1  분당선        Sunae   藪 內   일반역    NaN   NaN  37.378435
# 796   1857   정자역  I28K1  분당선      Jeongja   亭 子   환승역  I41D1  신분당선  37.366037
# 797   1858   미금역  I28K1  분당선       Migeum   美 金   일반역    NaN   NaN  37.350078
# 798   1859   오리역  I28K1  분당선          Ori   梧 里   일반역    NaN   NaN  37.339832
# 1059  1954   백석역  I4106  일산선     Baekseok   白 石   일반역    NaN   NaN  37.642973
# 1060  1955   마두역  I4106  일산선         Madu   馬 頭   일반역    NaN   NaN  37.652185
# ...

# %%
filtered_newtown
# Out:
#        역번호   역사명   노선번호  노선명        영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명        역위도  \
# 279   1502   이매역  I41K5  경강선         Imae    二梅   환승역  I28K1   분당선  37.394736
# 791   1853   모란역  I28K1  분당선        Moran   牡 丹   환승역  S1108   8호선  37.432124
# 792   1854   야탑역  I28K1  분당선        Yatap   野 塔   일반역    NaN   NaN  37.411320
# 793   1860   이매역  I28K1  분당선         Imae   二 梅   환승역  I41K5   경강선  37.395846
# 794   1855   서현역  I28K1  분당선     Seohyeon   書 峴   일반역    NaN   NaN  37.384931
# 795   1856   수내역  I28K1  분당선        Sunae   藪 內   일반역    NaN   NaN  37.378435
# 796   1857   정자역  I28K1  분당선      Jeongja   亭 子   환승역  I41D1  신분당선  37.366037
# 797   1858   미금역  I28K1  분당선       Migeum   美 金   일반역    NaN   NaN  37.350078
# 798   1859   오리역  I28K1  분당선          Ori   梧 里   일반역    NaN   NaN  37.339832
# 1059  1954   백석역  I4106  일산선     Baekseok   白 石   일반역    NaN   NaN  37.642973
# 1060  1955   마두역  I4106  일산선         Madu   馬 頭   일반역    NaN   NaN  37.652185
# ...
